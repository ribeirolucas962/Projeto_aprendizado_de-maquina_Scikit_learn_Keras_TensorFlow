# %%
pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (2.9.9)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~lotly (c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
from dotenv import load_dotenv
import os
import psycopg2

# %%
import os
os.environ['PGPASSFILE'] = 'NUL'

# %%
# Carrega o arquivo .env
import psycopg2

# POSGRES 16
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "viagem_milhas"
DB_USER = "postgres"
DB_PASSWORD = "postgres"

try:
    conexao = psycopg2.connect(
        f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
    )
    print("✅ Conexão bem-sucedida!")
except Exception as e:
    print("❌ Erro ao conectar:", e)
# Out:
# ✅ Conexão bem-sucedida!
